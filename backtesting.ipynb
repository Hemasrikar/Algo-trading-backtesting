# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn import preprocessing
import statsmodels.api as sm
from statsmodels.stats import descriptivestats
import seaborn as sns

# %%
df = pd.read_parquet("data/Trades_Quote.parquet")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991986 entries, 0 to 1991985
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   COMPANY     object
#  1   DATE        object
#  2   TRADE_TIME  datetime64[us]
#  3   QUOTE_TIME  datetime64[us]
#  4   EX          object
#  5   SIZE        int64
#  6   PRICE       float64
#  7   BID         float64
#  8   BIDSIZ      float64
#  9   ASK         float64
#  10  ASKSIZ      float64
# dtypes: datetime64[us](2), float64(5), int64(1), object(3)
# memory usage: 167.2+ MB
#   COMPANY        DATE                 TRADE_TIME                 QUOTE_TIME  \
# 0       C  2024-01-02 2024-01-02 09:32:40.845895 2024-01-02 09:32:40.842364
# 1       C  2024-01-02 2024-01-02 09:32:40.888035 2024-01-02 09:32:40.888012
# 2       C  2024-01-02 2024-01-02 09:32:40.888311 2024-01-02 09:32:40.888308
# 3       C  2024-01-02 2024-01-02 09:32:40.929882 2024-01-02 09:32:40.897981
# 4       C  2024-01-02 2024-01-02 09:32:40.953091 2024-01-02 09:32:40.937756
#
#   EX  SIZE  PRICE    BID  BIDSIZ    ASK  ASKSIZ
# 0  H   100  51.33  51.33     1.0  51.36     1.0
# 1  H   100  51.33  51.32     1.0  51.35     1.0
# 2  H    50  51.33  51.32     1.0  51.35     1.0
# 3  H   200  51.31  51.31     2.0  51.33     1.0
# 4  H     1  51.30  51.30     3.0  51.32     1.0

# %%
df = df.sort_values(by=['COMPANY', 'DATE', 'TRADE_TIME'])

# Create 1-minute interval
df['INTERVAL_TIME'] = df['TRADE_TIME'].dt.floor('min')

# Calculate Variables: last midprice, quoted spread, relative quoted spread, effective relative spread, order imbalance
# and depth imbalance, number of trades and total traded volume [+1-minute returns and relaized volatility over the past hour]

df['MID_PRICE'] = (df['BID'] + df['ASK']) / 2.0
df['QUOTED_SPREAD'] = df['ASK'] - df['BID']
df['RELATIVE_SPREAD'] = (df['QUOTED_SPREAD'] / df['MID_PRICE'].replace(0, np.nan))
df['EFFECTIVE_RELATIVE_SPREAD'] = (2 * np.abs((df['PRICE'] - df['MID_PRICE']) / df['MID_PRICE'].replace(0, np.nan)))
df['DEPTH_IMBALANCE'] = ((df['ASKSIZ'] - df['BIDSIZ']) / (df['BIDSIZ'] + df['ASKSIZ']).replace(0, np.nan))

# Classify trades as buyer-initiated or seller-initiated
# TODO: Check the Volume condition again, whether to multiply the size by respestive SIZE
df['BUY_VOLUME'] = np.where(df['PRICE'] >= df['ASK'], df['SIZE'], 0)
df['SELL_VOLUME'] = np.where(df['PRICE'] <= df['BID'], df['SIZE'], 0)

df.head()
# Out:
#       COMPANY        DATE                 TRADE_TIME  \
# 27823       C  2024-01-02 2024-01-02 09:30:00.940920
# 27824       C  2024-01-02 2024-01-02 09:30:00.940923
# 59906       C  2024-01-02 2024-01-02 09:30:00.943365
# 59907       C  2024-01-02 2024-01-02 09:30:00.943383
# 27825       C  2024-01-02 2024-01-02 09:30:01.061387
#
#                       QUOTE_TIME EX  SIZE  PRICE    BID  BIDSIZ    ASK  \
# 27823                        NaT  N   835  28.62    NaN     NaN    NaN
# 27824                        NaT  N   835  28.62    NaN     NaN    NaN
# 59906 2024-01-02 09:30:00.943363  T  3831  51.30  51.14     2.0  51.33
# 59907 2024-01-02 09:30:00.943363  T  3831  51.30  51.14     2.0  51.33
# 27825                        NaT  N  3020  25.59    NaN     NaN    NaN
#
#        ASKSIZ       INTERVAL_TIME  MID_PRICE  QUOTED_SPREAD  RELATIVE_SPREAD  \
# 27823     NaN 2024-01-02 09:30:00        NaN            NaN              NaN
# 27824     NaN 2024-01-02 09:30:00        NaN            NaN              NaN
# 59906    25.0 2024-01-02 09:30:00     51.235           0.19         0.003708
# 59907    25.0 2024-01-02 09:30:00     51.235           0.19         0.003708
# 27825     NaN 2024-01-02 09:30:00        NaN            NaN              NaN
#
#        EFFECTIVE_RELATIVE_SPREAD  DEPTH_IMBALANCE  BUY_VOLUME  SELL_VOLUME
# 27823                        NaN              NaN           0            0
# 27824                        NaN              NaN           0            0
# 59906                   0.002537         0.851852           0            0
# 59907                   0.002537         0.851852           0            0
# 27825                        NaN              NaN           0            0

# %%
tradesquotes = df.groupby(['COMPANY', 'DATE', 'INTERVAL_TIME']).agg(
    # Price and Spread Measures
    QUOTED_SPREAD_AVG=('QUOTED_SPREAD', 'mean'),
    RELATIVE_SPREAD_AVG=('RELATIVE_SPREAD', 'mean'),
    EFFECTIVE_RELATIVE_SPREAD_AVG=('EFFECTIVE_RELATIVE_SPREAD', 'mean'),

    # Last Mid-price for each 1-minute interval
    LAST_MID_PRICE=('MID_PRICE', 'last'),

    # Size / Depth Measures
    BID_SIZE_AVG=('BIDSIZ', 'mean'),
    ASK_SIZE_AVG=('ASKSIZ', 'mean'),
    DEPTH_IMBALANCE_AVG=('DEPTH_IMBALANCE', 'mean'),

    # Order Imbalance
    BUY_VOLUME_SUM=('BUY_VOLUME', 'sum'),
    SELL_VOLUME_SUM=('SELL_VOLUME', 'sum'),
    TOTAL_VOLUME_SUM=('SIZE', 'sum'),

    # Trade Intensity
    NUM_TRADES=('PRICE', 'count'),
    TOTAL_TRADED_VOLUME=('SIZE', 'sum')
).reset_index()

# Calculate Order Imbalance
tradesquotes['ORDER_IMBALANCE'] = ((tradesquotes['BUY_VOLUME_SUM'] - tradesquotes['SELL_VOLUME_SUM']) /
                              tradesquotes['TOTAL_VOLUME_SUM'].replace(0, np.nan))

# Sort by interval_time
tradesquotes = tradesquotes.sort_values(by=['COMPANY', 'DATE', 'INTERVAL_TIME']).reset_index(drop=True)

tradesquotes.head()
# Out:
#   COMPANY        DATE       INTERVAL_TIME  QUOTED_SPREAD_AVG  \
# 0       C  2024-01-02 2024-01-02 09:30:00           0.036966
# 1       C  2024-01-02 2024-01-02 09:31:00           0.042653
# 2       C  2024-01-02 2024-01-02 09:32:00           0.067746
# 3       C  2024-01-02 2024-01-02 09:33:00           0.080236
# 4       C  2024-01-02 2024-01-02 09:34:00           0.087648
#
#    RELATIVE_SPREAD_AVG  EFFECTIVE_RELATIVE_SPREAD_AVG  LAST_MID_PRICE  \
# 0             0.000721                       0.000293          51.250
# 1             0.000833                       0.000367          51.340
# 2             0.001336                       0.000924          51.485
# 3             0.001581                       0.002352          51.580
# 4             0.001741                       0.008247          51.675
#
#    BID_SIZE_AVG  ASK_SIZE_AVG  DEPTH_IMBALANCE_AVG  BUY_VOLUME_SUM  \
# 0      2.744828      3.200000             0.017096            3154
# 1      2.224490      2.546939             0.063801            3333
# 2      2.689589      5.562560             0.044754           22172
# 3      2.543906      2.503277            -0.041130           13154
# 4      3.194444      2.557407            -0.093922           13499
#
#    SELL_VOLUME_SUM  TOTAL_VOLUME_SUM  NUM_TRADES  TOTAL_TRADED_VOLUME  \
# 0             4669             41191         302                41191
# 1             4003             20013         248                20013
# 2            22192            619970        1049               619970
# 3             8734             72906         763                72906
# 4             3720             49435         540                49435
#
#    ORDER_IMBALANCE
# 0        -0.036780
# 1        -0.033478
# 2        -0.000032
# 3         0.060626
# 4         0.197815

# %%
#Calculate returns over previous 1-minute interval (for realized volatility) and over next 1-minute interval (as target/dependent variable)

# Check that last time interval is actually 1 minute apart
tradesquotes['LAST_INTERVAL_TIME'] = tradesquotes.groupby(['COMPANY', 'DATE'])['INTERVAL_TIME'].shift(+1)
tradesquotes['TIME_DIFF'] = (tradesquotes['LAST_INTERVAL_TIME'] - tradesquotes['INTERVAL_TIME']).dt.total_seconds() / 60

#Count how many observations with time gap> 1 minute
count = (tradesquotes['TIME_DIFF'] > 1.5).sum()
print(f"Number of observations set to 0: {count}")

# Calculate 1-min return over the previous 1-minute interval
tradesquotes['1MIN_RETURN'] = tradesquotes.groupby(['COMPANY', 'DATE'])['LAST_MID_PRICE'].pct_change()

# Set return to 0 if time gap is not 1 minute
tradesquotes.loc[tradesquotes['TIME_DIFF'] > 1, '1MIN_RETURN'] = 0

# Clean up temporary columns
tradesquotes = tradesquotes.drop(columns=['LAST_INTERVAL_TIME', 'TIME_DIFF'])

# Calculate tardet/dependent variable -  return over the next 1-minute interval.
# Set 1-minute returns to 0 if the next interval is more than 1 minute in the future

# Calculate return and check that it's actually 1 minute apart
tradesquotes['NEXT_INTERVAL_TIME'] = tradesquotes.groupby(['COMPANY', 'DATE'])['INTERVAL_TIME'].shift(-1)
tradesquotes['TIME_DIFF'] = (tradesquotes['NEXT_INTERVAL_TIME'] - tradesquotes['INTERVAL_TIME']).dt.total_seconds() / 60

# Calculate 1-minute return over next minute
tradesquotes['NEXT_1MIN_RETURN'] = tradesquotes.groupby(['COMPANY', 'DATE'])['LAST_MID_PRICE'].pct_change().shift(-1)

#Count how many observations with time gap> 1 minute

count = (tradesquotes['TIME_DIFF'] > 1.5).sum()

print(f"Number of observations set to 0: {count}")

# Set return to 0 if time gap is not 1 minute
tradesquotes.loc[tradesquotes['TIME_DIFF'] > 1, 'NEXT_1MIN_RETURN'] = 0

# Clean up temporary columns
tradesquotes = tradesquotes.drop(columns=['NEXT_INTERVAL_TIME', 'TIME_DIFF'])

display(tradesquotes.head())
tradesquotes.tail()
# Out:
# Number of observations set to 0: 0
# Number of observations set to 0: 0
#   COMPANY        DATE       INTERVAL_TIME  QUOTED_SPREAD_AVG  \
# 0       C  2024-01-02 2024-01-02 09:30:00           0.036966
# 1       C  2024-01-02 2024-01-02 09:31:00           0.042653
# 2       C  2024-01-02 2024-01-02 09:32:00           0.067746
# 3       C  2024-01-02 2024-01-02 09:33:00           0.080236
# 4       C  2024-01-02 2024-01-02 09:34:00           0.087648
#
#    RELATIVE_SPREAD_AVG  EFFECTIVE_RELATIVE_SPREAD_AVG  LAST_MID_PRICE  \
# 0             0.000721                       0.000293          51.250
# 1             0.000833                       0.000367          51.340
# 2             0.001336                       0.000924          51.485
# 3             0.001581                       0.002352          51.580
# 4             0.001741                       0.008247          51.675
#
#    BID_SIZE_AVG  ASK_SIZE_AVG  DEPTH_IMBALANCE_AVG  BUY_VOLUME_SUM  \
# 0      2.744828      3.200000             0.017096            3154
# 1      2.224490      2.546939             0.063801            3333
# 2      2.689589      5.562560             0.044754           22172
# 3      2.543906      2.503277            -0.041130           13154
# 4      3.194444      2.557407            -0.093922           13499
#
#    SELL_VOLUME_SUM  TOTAL_VOLUME_SUM  NUM_TRADES  TOTAL_TRADED_VOLUME  \
# 0             4669             41191         302                41191
# 1             4003             20013         248                20013
# 2            22192            619970        1049               619970
# 3             8734             72906         763                72906
# 4             3720             49435         540                49435
#
#    ORDER_IMBALANCE  1MIN_RETURN  NEXT_1MIN_RETURN
# 0        -0.036780          NaN          0.001756
# 1        -0.033478     0.001756          0.002824
# 2        -0.000032     0.002824          0.001845
# 3         0.060626     0.001845          0.001842
# 4         0.197815     0.001842         -0.003000
#      COMPANY        DATE       INTERVAL_TIME  QUOTED_SPREAD_AVG  \
# 8185       C  2024-01-31 2024-01-31 15:55:00           0.028586
# 8186       C  2024-01-31 2024-01-31 15:56:00           0.015129
# 8187       C  2024-01-31 2024-01-31 15:57:00           0.023812
# 8188       C  2024-01-31 2024-01-31 15:58:00           0.016405
# 8189       C  2024-01-31 2024-01-31 15:59:00           0.045426
#
#       RELATIVE_SPREAD_AVG  EFFECTIVE_RELATIVE_SPREAD_AVG  LAST_MID_PRICE  \
# 8185             0.000502                       0.006202          56.225
# 8186             0.000269                       0.109769          56.230
# 8187             0.000425                       0.089563          56.230
# 8188             0.000292                       0.013726          56.180
# 8189             0.000798                       0.043856          56.165
#
#       BID_SIZE_AVG  ASK_SIZE_AVG  DEPTH_IMBALANCE_AVG  BUY_VOLUME_SUM  \
# 8185     14.713816     13.915570            -0.032620           30955
# 8186     19.288710     24.066129             0.107084           14198
# 8187     23.054463     15.756430            -0.130577           22139
# 8188     27.283544     21.727848             0.031209           40756
# 8189     45.780396     25.106588            -0.068316           96370
#
#       SELL_VOLUME_SUM  TOTAL_VOLUME_SUM  NUM_TRADES  TOTAL_TRADED_VOLUME  \
# 8185            35059            116761         912               116761
# 8186            40098             93430         620                93430
# 8187            32353             99239         661                99239
# 8188            54053            141986         790               141986
# 8189           148032            380383        1867               380383
#
#       ORDER_IMBALANCE  1MIN_RETURN  NEXT_1MIN_RETURN
# 8185        -0.035149     0.000000          0.000089
# 8186        -0.277213     0.000089          0.000000
# 8187        -0.102923     0.000000         -0.000889
# 8188        -0.093650    -0.000889         -0.000267
# 8189        -0.135816    -0.000267               NaN

# %% [markdown]
# ### Winsorizing main variables at 1% and 99%

# %%
def winsorize_simple(df, columns, lower_percentile=1, upper_percentile=99):

    df_winsorized = df.copy()

    for col in columns:
        if col in df.columns:
            lower = df[col].quantile(lower_percentile / 100)
            upper = df[col].quantile(upper_percentile / 100)
            df_winsorized[col] = df[col].clip(lower, upper)

    return df_winsorized

variables_to_winsorize = [
    'RELATIVE_SPREAD_AVG',
    'EFFECTIVE_RELATIVE_SPREAD_AVG',
    'QUOTED_SPREAD_AVG',
    'LAST_MID_PRICE',
    'DEPTH_IMBALANCE_AVG',
    'ORDER_IMBALANCE',
    'TOTAL_TRADED_VOLUME',
    'NUM_TRADES',
    '1MIN_RETURN',
    'NEXT_1MIN_RETURN',

]

# Apply
mkt_data = winsorize_simple(tradesquotes, variables_to_winsorize)

print("Winsorization complete!")
print(f"Original shape: {tradesquotes.shape}")
print(f"Winsorized shape: {mkt_data.shape}")

#Check summary stats
print(mkt_data['NEXT_1MIN_RETURN'].describe())
print(mkt_data['ORDER_IMBALANCE'].describe())
print(mkt_data['DEPTH_IMBALANCE_AVG'].describe())
print(mkt_data['TOTAL_TRADED_VOLUME'].describe())
print(mkt_data['RELATIVE_SPREAD_AVG'].describe())


# Calculate realized volatility as sum of squared 1-minute returns over the past hour

# Sort by interval_time
mkt_data = mkt_data.sort_values(by=['COMPANY', 'DATE', 'INTERVAL_TIME']).reset_index(drop=True)


mkt_data['REALIZED_VOLAT'] = (
    mkt_data.groupby(['COMPANY', 'DATE'])['1MIN_RETURN']
    .rolling(window=60, min_periods=5)
    .apply(lambda x: (x**2).sum())
    .reset_index(level=[0, 1], drop=True)
)

# winsorize realized volatility
variables_to_winsorize = ['REALIZED_VOLAT']
mkt_data = winsorize_simple(mkt_data, variables_to_winsorize)

print(mkt_data['REALIZED_VOLAT'].describe())
mkt_data.head()
# Out:
# Winsorization complete!
# Original shape: (8190, 18)
# Winsorized shape: (8190, 18)
# count    8169.000000
# mean        0.000030
# std         0.004636
# min        -0.023313
# 25%        -0.000374
# 50%         0.000000
# 75%         0.000380
# max         0.023968
# Name: NEXT_1MIN_RETURN, dtype: float64
# count    8190.000000
# mean       -0.004233
# std         0.193452
# min        -0.475979
# 25%        -0.130914
# 50%        -0.005855
# 75%         0.121734
# max         0.476881
# Name: ORDER_IMBALANCE, dtype: float64
# count    8190.000000
# mean       -0.021701
# std         0.131310
# min        -0.349430
# 25%        -0.101839
# 50%        -0.018807
# 75%         0.060236
# max         0.309235
# Name: DEPTH_IMBALANCE_AVG, dtype: float64
# count      8190.000000
# mean      26271.779883
# std       28541.112960
# min        2068.350000
# 25%       10109.000000
# 50%       17141.500000
# 75%       30213.000000
# max      181136.970000
# Name: TOTAL_TRADED_VOLUME, dtype: float64
# count    8190.000000
# mean        0.001347
# std         0.001205
# min         0.000263
# 25%         0.000514
# 50%         0.000986
# 75%         0.001715
# max         0.006965
# Name: RELATIVE_SPREAD_AVG, dtype: float64
# count    8085.000000
# mean        0.001215
# std         0.001044
# min         0.000009
# 25%         0.000310
# 50%         0.001126
# 75%         0.001860
# max         0.004475
# Name: REALIZED_VOLAT, dtype: float64
#   COMPANY        DATE       INTERVAL_TIME  QUOTED_SPREAD_AVG  \
# 0       C  2024-01-02 2024-01-02 09:30:00           0.036966
# 1       C  2024-01-02 2024-01-02 09:31:00           0.042653
# 2       C  2024-01-02 2024-01-02 09:32:00           0.067746
# 3       C  2024-01-02 2024-01-02 09:33:00           0.080236
# 4       C  2024-01-02 2024-01-02 09:34:00           0.087648
#
#    RELATIVE_SPREAD_AVG  EFFECTIVE_RELATIVE_SPREAD_AVG  LAST_MID_PRICE  \
# 0             0.000721                       0.000293          51.250
# 1             0.000833                       0.000367          51.340
# 2             0.001336                       0.000924          51.485
# 3             0.001581                       0.002352          51.580
# 4             0.001741                       0.008247          51.675
#
#    BID_SIZE_AVG  ASK_SIZE_AVG  DEPTH_IMBALANCE_AVG  BUY_VOLUME_SUM  \
# 0      2.744828      3.200000             0.017096            3154
# 1      2.224490      2.546939             0.063801            3333
# 2      2.689589      5.562560             0.044754           22172
# 3      2.543906      2.503277            -0.041130           13154
# 4      3.194444      2.557407            -0.093922           13499
#
#    SELL_VOLUME_SUM  TOTAL_VOLUME_SUM  NUM_TRADES  TOTAL_TRADED_VOLUME  \
# 0             4669             41191       302.0             41191.00
# 1             4003             20013       248.0             20013.00
# 2            22192            619970      1049.0            181136.97
# 3             8734             72906       763.0             72906.00
# 4             3720             49435       540.0             49435.00
#
#    ORDER_IMBALANCE  1MIN_RETURN  NEXT_1MIN_RETURN  REALIZED_VOLAT
# 0        -0.036780          NaN          0.001756             NaN
# 1        -0.033478     0.001756          0.002824             NaN
# 2        -0.000032     0.002824          0.001845             NaN
# 3         0.060626     0.001845          0.001842             NaN
# 4         0.197815     0.001842         -0.003000             NaN

# %%
features = ['ORDER_IMBALANCE', 'DEPTH_IMBALANCE_AVG', 'RELATIVE_SPREAD_AVG','TOTAL_TRADED_VOLUME','REALIZED_VOLAT']
target = "NEXT_1MIN_RETURN"

print(features+[target])
print(descriptivestats.Description(mkt_data[features + [target]]))
# Out:
# ['ORDER_IMBALANCE', 'DEPTH_IMBALANCE_AVG', 'RELATIVE_SPREAD_AVG', 'TOTAL_TRADED_VOLUME', 'REALIZED_VOLAT', 'NEXT_1MIN_RETURN']
#                             Descriptive Statistics
# ==============================================================================
# nobs                   8190     8190      8190      8190       8190       8190
# missing                   0        0         0         0        105         21
# mean              -0.004233  -0.0217  0.001347 2.627e+04   0.001215  3.002e-05
# std_err            0.002138 0.001451 1.332e-05     315.4  1.161e-05  5.129e-05
# upper_ci         -4.295e-05 -0.01886  0.001373 2.689e+04   0.001238  0.0001306
# lower_ci          -0.008422 -0.02455  0.001321 2.565e+04   0.001192 -7.052e-05
# std                  0.1935   0.1313  0.001205 2.854e+04   0.001044   0.004636
# iqr                  0.2526   0.1621    0.0012     20104    0.00155  0.0007539
# iqr_normal           0.1873   0.1201 0.0008897  1.49e+04   0.001149  0.0005589
# mad                  0.1533   0.1026 0.0008537 1.814e+04  0.0008262   0.001563
# mad_normal           0.1921   0.1286   0.00107 2.273e+04   0.001036   0.001959
# coef_var             -45.71   -6.051    0.8949     1.086     0.8596      154.4
# range                0.9529   0.6587  0.006703 1.791e+05   0.004466    0.04728
# max                  0.4769   0.3092  0.006965 1.811e+05   0.004475    0.02397
# min                  -0.476  -0.3494 0.0002626      2068  9.041e-06   -0.02331
# skew                0.03228 -0.05039     2.164     3.041     0.9143      0.187
# kurtosis              2.845    3.017     8.779     14.34      3.345      20.74
# jarque_bera           9.668    3.568 1.779e+04 5.652e+04       1166  1.072e+05
# jarque_bera_pval   0.007953    0.168         0         0 5.025e-254          0
# mode                 -0.476  -0.3494 0.0002626      2068  9.041e-06          0
# mode_freq           0.01001  0.01001   0.01001   0.01001    0.01002    0.08777
# median            -0.005855 -0.01881 0.0009858 1.714e+04   0.001126          0
# 1%                  -0.4759  -0.3494 0.0002626      2070  9.042e-06   -0.02331
# 5%                  -0.3283  -0.2513  0.000296      4645  1.457e-05   -0.00176
# 10%                 -0.2522  -0.1964 0.0003222      6345   4.34e-05 -0.0009333
# 25%                 -0.1309  -0.1018 0.0005144     10109  0.0003105  -0.000374
# 50%               -0.005855 -0.01881 0.0009858 1.714e+04   0.001126          0
# 75%                  0.1217  0.06024  0.001715     30213    0.00186  0.0003799
# 90%                  0.2463   0.1408  0.002795 5.508e+04   0.002665  0.0009503
# 95%                  0.3274   0.1953  0.003784 7.999e+04   0.003287   0.001899
# 99%                  0.4769   0.3092  0.006965 1.811e+05   0.004475    0.02397
# ------------------------------------------------------------------------------

# %% [markdown]
# ### Correlation Matrix

# %%
print(mkt_data[features].corr())
plt.figure(figsize=(10,8))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(mkt_data[features].corr(), annot=False, cmap="viridis", center=0)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
#                      ORDER_IMBALANCE  DEPTH_IMBALANCE_AVG  \
# ORDER_IMBALANCE             1.000000            -0.601551
# DEPTH_IMBALANCE_AVG        -0.601551             1.000000
# RELATIVE_SPREAD_AVG        -0.029916             0.046134
# TOTAL_TRADED_VOLUME         0.001199             0.054043
# REALIZED_VOLAT              0.003964            -0.042518
#
#                      RELATIVE_SPREAD_AVG  TOTAL_TRADED_VOLUME  REALIZED_VOLAT
# ORDER_IMBALANCE                -0.029916             0.001199        0.003964
# DEPTH_IMBALANCE_AVG             0.046134             0.054043       -0.042518
# RELATIVE_SPREAD_AVG             1.000000            -0.031993        0.037685
# TOTAL_TRADED_VOLUME            -0.031993             1.000000       -0.018074
# REALIZED_VOLAT                  0.037685            -0.018074        1.000000

# %% [markdown]
# ### Graphs

# %%
df1 =mkt_data.copy()
df1 = df1.drop(['COMPANY', 'DATE', 'INTERVAL_TIME'], axis=1)
mkt_data[features].hist(bins=40, figsize=(15,12))
plt.suptitle(f"Feature Distributions", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Regression using StatsModels

# %%
df2 = mkt_data.copy()
df2 = df2.sort_values(by=['COMPANY', 'DATE', 'INTERVAL_TIME']).reset_index(drop=True)
df2 = df2.dropna(subset=features + [target])

features = ['ORDER_IMBALANCE','RELATIVE_SPREAD_AVG','TOTAL_TRADED_VOLUME','REALIZED_VOLAT']
X = df2[features]
Y  = df2['NEXT_1MIN_RETURN']
scaler = preprocessing.StandardScaler()
X_scaled = scaler.fit_transform(X)

# Add a constant for the intercept term
X_const = sm.add_constant(X_scaled)

reg_model = sm.OLS(Y, X_const)
results = reg_model.fit(cov_type='HC1')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       NEXT_1MIN_RETURN   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.953
# Date:                Sat, 11 Apr 2026   Prob (F-statistic):             0.0988
# Time:                        00:43:04   Log-Likelihood:                 32099.
# No. Observations:                8064   AIC:                        -6.419e+04
# Df Residuals:                    8059   BIC:                        -6.415e+04
# Df Model:                           4
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.372e-05   5.03e-05      0.471      0.638    -7.5e-05       0.000
# x1            -0.0001   4.93e-05     -2.173      0.030      -0.000   -1.05e-05
# x2          9.919e-05   6.52e-05      1.521      0.128   -2.86e-05       0.000
# x3         -4.012e-05    5.7e-05     -0.704      0.481      -0.000    7.16e-05
# x4          1.372e-05   5.42e-05      0.253      0.800   -9.24e-05       0.000
# ==============================================================================
# Omnibus:                     1939.027   Durbin-Watson:                   2.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           116690.421
# Skew:                           0.130   Prob(JB):                         0.00
# Kurtosis:                      21.634   Cond. No.                         1.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# ### Regression using SkLearn

# %%
mkt_data = mkt_data.dropna(subset=features + ['NEXT_1MIN_RETURN'])
X = mkt_data[features]
Y  = mkt_data['NEXT_1MIN_RETURN']

scaler = preprocessing.StandardScaler()
X_scaled = scaler.fit_transform(X)
regression = linear_model.LinearRegression()
regression.fit(X_scaled, Y)

print(regression.coef_)
print(regression.intercept_)
# Out:
# [-1.07093917e-04  9.91867039e-05 -4.01170706e-05  1.37185475e-05]
# 2.3715618760735628e-05

# %% [markdown]
# ## Out of Sample Testing - Linear Regression Using SkLearn

# %% [markdown]
# ### Train Test Data Split

# %%
# variable_type variable_name variable_description
# Drop rows with missing values (especially for NEXT_RETURN)
mkt_data = mkt_data.dropna(subset=features + ['NEXT_1MIN_RETURN'])
X = mkt_data[features]
Y  = mkt_data['NEXT_1MIN_RETURN']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=24, shuffle=False)

scaler = preprocessing.StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Linear Regression

# %%
regression = linear_model.LinearRegression(n_jobs=-1, fit_intercept=True)
regression.fit(X_train_scaled, y_train)

print(regression.coef_)
print(regression.intercept_)
# Out:
# [-1.17391114e-04  4.47799153e-05 -4.26496590e-05  6.89673986e-06]
# 2.4252791710236362e-05
